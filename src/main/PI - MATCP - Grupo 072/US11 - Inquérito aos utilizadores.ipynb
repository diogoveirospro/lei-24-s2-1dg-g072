# %% [markdown]
# # US11 - Inquérito aos utilizadores do parque

# %% [markdown]
# ## 1. Introdução

# %% [markdown]
# $\textbf{Nesta User Story (US11)}$, foi-nos pedido a realização de uma análise estatistica relativa ao uso do parque pelos vários utentes. Para isso um questionário com três perguntas será apresentado aos utentes.
# Este arquivo contém o questionário a ser realizado pelos utentes.

# %% [markdown]
# ## 2. Código e Resultados

# %%
print('Escolha o seu intervalo de idade:\n1 - Criança (até 15 anos)\n2 - Adulto (entre os 16 e os 65 anos)\n3 - Senior (mais de 65 anos)')
idade = int(input())
numUtentes = 0
numCriancas = 0
numAdultos = 0
numSeniores = 0

if idade == 1:
    numCriancas = numCriancas + 1
    numUtentes = numUtentes + 1
elif idade == 2:
    numAdultos = numAdultos + 1
    numUtentes = numUtentes + 1
elif idade == 3:
    numSeniores = numSeniores + 1
    numUtentes = numUtentes + 1

print('Recomendaria o parque a outras pessoas?\nY - Sim\nN - Não')
recomendacao = input()

numeroVisitas = int(input('Quantas vezes visita o parque por mês?\n'))
# Out:
# Escolha o seu intervalo de idade:
# 1 - Criança (até 15 anos)
# 2 - Adulto (entre os 16 e os 65 anos)
# 3 - Senior (mais de 65 anos)
# 1
# Recomendaria o parque a outras pessoas?
# Y - Sim
# N - Não
# y
# Quantas vezes visita o parque por mês?
# 123
